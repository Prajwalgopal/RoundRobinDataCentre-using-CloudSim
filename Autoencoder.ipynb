# %% [markdown]
# <a href="https://colab.research.google.com/github/nikeshhegde/RoundRobinDataCentre/blob/master/Autoencoder.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

#try:
  # The %tensorflow_version magic only works in colab.
  # tensorflow_version 2.x
#except Exception:
#  pass
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf


from tensorflow.keras.datasets import mnist

print('TensorFlow version:', tf.__version__)
print('Is Executing Eagerly?', tf.executing_eagerly())
# Out:
# TensorFlow version: 2.2.0-rc2
# Is Executing Eagerly? True

# %% [markdown]
# ## **BASIC AUTOENCODER**

# %% [markdown]
# ## **BASE MODEL**

# %%
class Encoder(tf.keras.layers.Layer):
    def __init__(self, intermediate_dim):
        super(Encoder, self).__init__()
        self.hidden_layer = tf.keras.layers.Dense(units=intermediate_dim, activation=tf.nn.relu)
        self.output_layer = tf.keras.layers.Dense(units=intermediate_dim, activation=tf.nn.relu)
    
    def call(self, input_features):
        activation = self.hidden_layer(input_features)
        return self.output_layer(activation)

class Decoder(tf.keras.layers.Layer):
    def __init__(self, intermediate_dim, original_dim):
        super(Decoder, self).__init__()
        self.hidden_layer = tf.keras.layers.Dense(units=intermediate_dim, activation=tf.nn.relu)
        self.output_layer = tf.keras.layers.Dense(units=original_dim, activation=tf.nn.relu)
  
    def call(self, code):
        activation = self.hidden_layer(code)
        return self.output_layer(activation)

class Autoencoder(tf.keras.Model):
  def __init__(self, intermediate_dim, original_dim):
    super(Autoencoder, self).__init__()
    self.loss = []
    self.encoder = Encoder(intermediate_dim=intermediate_dim)
    self.decoder = Decoder(intermediate_dim=intermediate_dim, original_dim=original_dim)

  def call(self, input_features):
    code = self.encoder(input_features)
    reconstructed = self.decoder(code)
    return reconstructed

def loss(preds, real):
  return tf.reduce_mean(tf.square(tf.subtract(preds, real)))

def train(loss, model, opt, original):
  with tf.GradientTape() as tape:
    preds = model(original)
    reconstruction_error = loss(preds, original)
  gradients = tape.gradient(reconstruction_error, model.trainable_variables)
  gradient_variables = zip(gradients, model.trainable_variables)
  opt.apply_gradients(gradient_variables)
  
  return reconstruction_error

def train_loop(model, opt, loss, dataset, epochs):
  for epoch in range(epochs):
    epoch_loss = 0
    for step, batch_features in enumerate(dataset):
      loss_values = train(loss, model, opt, batch_features)
      epoch_loss += loss_values
    model.loss.append(epoch_loss)
    print('Epoch {}/{}. Loss: {}'.format(epoch + 1, epochs, epoch_loss.numpy()))
from tensorflow.keras.datasets import mnist
(x_train, _), (x_test, _) = mnist.load_data()

x_train = x_train / 255.

x_train = x_train.astype(np.float32)
x_train = np.reshape(x_train, (x_train.shape[0], 784))
x_test = np.reshape(x_test, (x_test.shape[0], 784))

training_dataset = tf.data.Dataset.from_tensor_slices(x_train).batch(256)

model = Autoencoder(intermediate_dim=128, original_dim=784)
opt = tf.keras.optimizers.Adam(learning_rate=1e-2)
train_loop(model, opt, loss, training_dataset, 100)

plt.plot(range(100), model.loss)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

number = 10  # how many digits we will display
plt.figure(figsize=(20, 4))
for index in range(number):
    # display original
    ax = plt.subplot(2, number, index + 1)
    plt.imshow(x_test[index].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display reconstruction
    ax = plt.subplot(2, number, index + 1 + number)
    plt.imshow(model(x_test)[index].numpy().reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
# Out:
# Epoch 1/100. Loss: 8.630229949951172
# Epoch 2/100. Loss: 5.505133628845215
# Epoch 3/100. Loss: 5.07551383972168
# Epoch 4/100. Loss: 4.855296611785889
# Epoch 5/100. Loss: 4.742985248565674
# Epoch 6/100. Loss: 4.681737899780273
# Epoch 7/100. Loss: 4.644071102142334
# Epoch 8/100. Loss: 4.587369441986084
# Epoch 9/100. Loss: 4.556818008422852
# Epoch 10/100. Loss: 4.505757808685303
# Epoch 11/100. Loss: 4.500783920288086
# Epoch 12/100. Loss: 4.474051475524902
# Epoch 13/100. Loss: 4.47385311126709
# Epoch 14/100. Loss: 4.4467363357543945
# Epoch 15/100. Loss: 4.398472309112549
# Epoch 16/100. Loss: 4.397387981414795
# Epoch 17/100. Loss: 4.4098124504089355
# Epoch 18/100. Loss: 4.3915605545043945
# Epoch 19/100. Loss: 4.368079662322998
# Epoch 20/100. Loss: 4.383944511413574
# Epoch 21/100. Loss: 4.381008148193359
# Epoch 22/100. Loss: 4.380582809448242
# Epoch 23/100. Loss: 4.3898091316223145
# Epoch 24/100. Loss: 4.386039733886719
# Epoch 25/100. Loss: 4.354583263397217
# Epoch 26/100. Loss: 4.348464012145996
# Epoch 27/100. Loss: 4.338077545166016
# Epoch 28/100. Loss: 4.3449530601501465
# Epoch 29/100. Loss: 4.353868007659912
# Epoch 30/100. Loss: 4.336703777313232
# Epoch 31/100. Loss: 4.318284511566162
# Epoch 32/100. Loss: 4.329904556274414
# Epoch 33/100. Loss: 4.316037654876709
# Epoch 34/100. Loss: 4.329932689666748
# Epoch 35/100. Loss: 4.319241046905518
# Epoch 36/100. Loss: 4.306300640106201
# Epoch 37/100. Loss: 4.297341346740723
# Epoch 38/100. Loss: 4.304287433624268
# Epoch 39/100. Loss: 4.307992458343506
# Epoch 40/100. Loss: 4.323298454284668
# Epoch 41/100. Loss: 4.280980110168457
# Epoch 42/100. Loss: 4.3067779541015625
# Epoch 43/100. Loss: 4.272975921630859
# Epoch 44/100. Loss: 4.316469192504883
# Epoch 45/100. Loss: 4.291877746582031
# Epoch 46/100. Loss: 4.290958404541016
# Epoch 47/100. Loss: 4.281445026397705
# Epoch 48/100. Loss: 4.286330699920654
# Epoch 49/100. Loss: 4.274056434631348
# Epoch 50/100. Loss: 4.275731563568115
# Epoch 51/100. Loss: 4.283188343048096
# Epoch 52/100. Loss: 4.282011032104492
# Epoch 53/100. Loss: 4.298058986663818
# Epoch 54/100. Loss: 4.28963041305542
# Epoch 55/100. Loss: 4.262008190155029
# Epoch 56/100. Loss: 4.289764404296875
# Epoch 57/100. Loss: 4.284843444824219
# Epoch 58/100. Loss: 4.268777847290039
# Epoch 59/100. Loss: 4.260139465332031
# Epoch 60/100. Loss: 4.26497220993042
# Epoch 61/100. Loss: 4.268620014190674
# Epoch 62/100. Loss: 4.239599227905273
# Epoch 63/100. Loss: 4.237181663513184
# Epoch 64/100. Loss: 4.2531514167785645
# Epoch 65/100. Loss: 4.250644207000732
# Epoch 66/100. Loss: 4.245290279388428
# Epoch 67/100. Loss: 4.262279987335205
# Epoch 68/100. Loss: 4.221799850463867
# Epoch 69/100. Loss: 4.258216857910156
# Epoch 70/100. Loss: 4.275954723358154
# Epoch 71/100. Loss: 4.255296230316162
# Epoch 72/100. Loss: 4.235550880432129
# Epoch 73/100. Loss: 4.242822170257568
# Epoch 74/100. Loss: 4.232641696929932
# Epoch 75/100. Loss: 4.236782073974609
# Epoch 76/100. Loss: 4.260963439941406
# Epoch 77/100. Loss: 4.269896984100342
# Epoch 78/100. Loss: 4.275442600250244
# Epoch 79/100. Loss: 4.263763427734375
# Epoch 80/100. Loss: 4.235792636871338
# Epoch 81/100. Loss: 4.2650370597839355
# Epoch 82/100. Loss: 4.226449489593506
# Epoch 83/100. Loss: 4.245787143707275
# Epoch 84/100. Loss: 4.252013206481934
# Epoch 85/100. Loss: 4.231203556060791
# Epoch 86/100. Loss: 4.2401227951049805
# Epoch 87/100. Loss: 4.255126476287842
# Epoch 88/100. Loss: 4.242499828338623
# Epoch 89/100. Loss: 4.266830921173096
# Epoch 90/100. Loss: 4.2317094802856445
# Epoch 91/100. Loss: 4.238396167755127
# Epoch 92/100. Loss: 4.229467868804932
# Epoch 93/100. Loss: 4.224111080169678
# Epoch 94/100. Loss: 4.221494674682617
# Epoch 95/100. Loss: 4.2230987548828125
# Epoch 96/100. Loss: 4.237574100494385
# Epoch 97/100. Loss: 4.230325222015381
# Epoch 98/100. Loss: 4.207747936248779
# Epoch 99/100. Loss: 4.20958948135376
# Epoch 100/100. Loss: 4.192722320556641

# %% [markdown]
# ## **ADDING 1 LAYER**

# %%
class Encoder(tf.keras.layers.Layer):
    def __init__(self, intermediate_dim):
        super(Encoder, self).__init__()
        self.hidden_layer1 = tf.keras.layers.Dense(units=intermediate_dim, activation=tf.nn.relu)
        self.hidden_layer2 = tf.keras.layers.Dense(units=intermediate_dim, activation=tf.nn.relu)
        self.output_layer = tf.keras.layers.Dense(units=intermediate_dim, activation=tf.nn.relu)
    
    def call(self, input_features):

        activation1 = self.hidden_layer1(input_features)
        activation2 = self.hidden_layer2(activation1)
        return self.output_layer(activation2)

class Decoder(tf.keras.layers.Layer):
    def __init__(self, intermediate_dim, original_dim):
        super(Decoder, self).__init__()
        self.hidden_layer1 = tf.keras.layers.Dense(units=intermediate_dim, activation=tf.nn.relu)
        self.hidden_layer2 = tf.keras.layers.Dense(units=intermediate_dim, activation=tf.nn.relu)
        self.output_layer = tf.keras.layers.Dense(units=original_dim, activation=tf.nn.relu)
  
    def call(self, code):
        activation1 = self.hidden_layer1(code)
        activation2 = self.hidden_layer2(activation1)
        return self.output_layer(activation2)

class Autoencoder(tf.keras.Model):
  def __init__(self, intermediate_dim, original_dim):
    super(Autoencoder, self).__init__()
    self.loss = []
    self.encoder = Encoder(intermediate_dim=intermediate_dim)
    self.decoder = Decoder(intermediate_dim=intermediate_dim, original_dim=original_dim)

  def call(self, input_features):
    code = self.encoder(input_features)
    reconstructed = self.decoder(code)
    return reconstructed

def loss(preds, real):
  return tf.reduce_mean(tf.square(tf.subtract(preds, real)))

def train(loss, model, opt, original):
  with tf.GradientTape() as tape:
    preds = model(original)
    reconstruction_error = loss(preds, original)
  gradients = tape.gradient(reconstruction_error, model.trainable_variables)
  gradient_variables = zip(gradients, model.trainable_variables)
  opt.apply_gradients(gradient_variables)
  
  return reconstruction_error

def train_loop(model, opt, loss, dataset, epochs):
  for epoch in range(epochs):
    epoch_loss = 0
    for step, batch_features in enumerate(dataset):
      loss_values = train(loss, model, opt, batch_features)
      epoch_loss += loss_values
    model.loss.append(epoch_loss)
    print('Epoch {}/{}. Loss: {}'.format(epoch + 1, epochs, epoch_loss.numpy()))
from tensorflow.keras.datasets import mnist
(x_train, _), (x_test, _) = mnist.load_data()

x_train = x_train / 255.

x_train = x_train.astype(np.float32)
x_train = np.reshape(x_train, (x_train.shape[0], 784))
x_test = np.reshape(x_test, (x_test.shape[0], 784))

training_dataset = tf.data.Dataset.from_tensor_slices(x_train).batch(256)

model = Autoencoder(intermediate_dim=128, original_dim=784)
opt = tf.keras.optimizers.Adam(learning_rate=1e-2)
train_loop(model, opt, loss, training_dataset, 100)

plt.plot(range(100), model.loss)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

number = 10  # how many digits we will display
plt.figure(figsize=(20, 4))
for index in range(number):
    # display original
    ax = plt.subplot(2, number, index + 1)
    plt.imshow(x_test[index].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display reconstruction
    ax = plt.subplot(2, number, index + 1 + number)
    plt.imshow(model(x_test)[index].numpy().reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
# Out:
# Epoch 1/100. Loss: 12.016135215759277
# Epoch 2/100. Loss: 7.665579795837402
# Epoch 3/100. Loss: 6.599884033203125
# Epoch 4/100. Loss: 5.985152721405029
# Epoch 5/100. Loss: 5.605352401733398
# Epoch 6/100. Loss: 5.209237098693848
# Epoch 7/100. Loss: 5.038447380065918
# Epoch 8/100. Loss: 4.8618292808532715
# Epoch 9/100. Loss: 4.763729095458984
# Epoch 10/100. Loss: 4.665786266326904
# Epoch 11/100. Loss: 4.5991435050964355
# Epoch 12/100. Loss: 4.602227687835693
# Epoch 13/100. Loss: 4.500114440917969
# Epoch 14/100. Loss: 4.527431011199951
# Epoch 15/100. Loss: 4.483517169952393
# Epoch 16/100. Loss: 4.405885696411133
# Epoch 17/100. Loss: 4.388101577758789
# Epoch 18/100. Loss: 4.361225605010986
# Epoch 19/100. Loss: 4.350255012512207
# Epoch 20/100. Loss: 4.3372039794921875
# Epoch 21/100. Loss: 4.314842700958252
# Epoch 22/100. Loss: 4.2635369300842285
# Epoch 23/100. Loss: 4.270761966705322
# Epoch 24/100. Loss: 4.271515369415283
# Epoch 25/100. Loss: 4.227436542510986
# Epoch 26/100. Loss: 4.23374605178833
# Epoch 27/100. Loss: 4.188443183898926
# Epoch 28/100. Loss: 4.237961769104004
# Epoch 29/100. Loss: 4.198406219482422
# Epoch 30/100. Loss: 4.179804801940918
# Epoch 31/100. Loss: 4.185964107513428
# Epoch 32/100. Loss: 4.254120349884033
# Epoch 33/100. Loss: 4.211536884307861
# Epoch 34/100. Loss: 4.178700923919678
# Epoch 35/100. Loss: 4.170318603515625
# Epoch 36/100. Loss: 4.188040733337402
# Epoch 37/100. Loss: 4.149538040161133
# Epoch 38/100. Loss: 4.208298206329346
# Epoch 39/100. Loss: 4.118554592132568
# Epoch 40/100. Loss: 4.1664557456970215
# Epoch 41/100. Loss: 4.1633148193359375
# Epoch 42/100. Loss: 4.174478530883789
# Epoch 43/100. Loss: 4.144101619720459
# Epoch 44/100. Loss: 4.149031162261963
# Epoch 45/100. Loss: 4.117559909820557
# Epoch 46/100. Loss: 4.120771884918213
# Epoch 47/100. Loss: 4.153232574462891
# Epoch 48/100. Loss: 4.104361534118652
# Epoch 49/100. Loss: 4.110506057739258
# Epoch 50/100. Loss: 4.143432140350342
# Epoch 51/100. Loss: 4.125307559967041
# Epoch 52/100. Loss: 4.102237701416016
# Epoch 53/100. Loss: 4.077236175537109
# Epoch 54/100. Loss: 4.087112903594971
# Epoch 55/100. Loss: 4.1459736824035645
# Epoch 56/100. Loss: 4.107766151428223
# Epoch 57/100. Loss: 4.109488010406494
# Epoch 58/100. Loss: 4.089563369750977
# Epoch 59/100. Loss: 4.082537651062012
# Epoch 60/100. Loss: 4.096456527709961
# Epoch 61/100. Loss: 4.134212493896484
# Epoch 62/100. Loss: 4.055457592010498
# Epoch 63/100. Loss: 4.072777271270752
# Epoch 64/100. Loss: 4.0830535888671875
# Epoch 65/100. Loss: 4.050013065338135
# Epoch 66/100. Loss: 4.085974216461182
# Epoch 67/100. Loss: 4.074770450592041
# Epoch 68/100. Loss: 4.065980434417725
# Epoch 69/100. Loss: 4.094082355499268
# Epoch 70/100. Loss: 4.122071266174316
# Epoch 71/100. Loss: 4.083370208740234
# Epoch 72/100. Loss: 4.057425022125244
# Epoch 73/100. Loss: 4.093441963195801
# Epoch 74/100. Loss: 4.10723352432251
# Epoch 75/100. Loss: 4.056408405303955
# Epoch 76/100. Loss: 4.053194522857666
# Epoch 77/100. Loss: 4.069694995880127
# Epoch 78/100. Loss: 4.048372745513916
# Epoch 79/100. Loss: 4.077885627746582
# Epoch 80/100. Loss: 4.0678911209106445
# Epoch 81/100. Loss: 4.061822414398193
# Epoch 82/100. Loss: 4.053753852844238
# Epoch 83/100. Loss: 4.063591957092285
# Epoch 84/100. Loss: 4.086316108703613
# Epoch 85/100. Loss: 4.018776893615723
# Epoch 86/100. Loss: 4.054952621459961
# Epoch 87/100. Loss: 4.065857887268066
# Epoch 88/100. Loss: 4.078667163848877
# Epoch 89/100. Loss: 4.049930095672607
# Epoch 90/100. Loss: 4.074648857116699
# Epoch 91/100. Loss: 4.085824489593506
# Epoch 92/100. Loss: 4.069881439208984
# Epoch 93/100. Loss: 4.053110599517822
# Epoch 94/100. Loss: 4.044916152954102
# Epoch 95/100. Loss: 4.067872047424316
# Epoch 96/100. Loss: 4.091183662414551
# Epoch 97/100. Loss: 4.049456596374512
# Epoch 98/100. Loss: 4.049150466918945
# Epoch 99/100. Loss: 4.040632247924805
# Epoch 100/100. Loss: 4.053072452545166

# %% [markdown]
# ## **ADDING 1 LAYER AND IMPLEMENTING SANDWICH DIMENSIONS**

# %%
class Encoder(tf.keras.layers.Layer):
    def __init__(self, intermediate_dim):
        super(Encoder, self).__init__()
        self.hidden_layer1 = tf.keras.layers.Dense(units=intermediate_dim, activation=tf.nn.relu)
        self.hidden_layer2 = tf.keras.layers.Dense(units=intermediate_dim/2, activation=tf.nn.relu)
        self.output_layer = tf.keras.layers.Dense(units=intermediate_dim/4, activation=tf.nn.relu)
    
    def call(self, input_features):

        activation1 = self.hidden_layer1(input_features)
        activation2 = self.hidden_layer2(activation1)
        return self.output_layer(activation2)

class Decoder(tf.keras.layers.Layer):
    def __init__(self, intermediate_dim, original_dim):
        super(Decoder, self).__init__()
        self.hidden_layer1 = tf.keras.layers.Dense(units=intermediate_dim/2, activation=tf.nn.relu)
        self.hidden_layer2 = tf.keras.layers.Dense(units=intermediate_dim, activation=tf.nn.relu)
        self.output_layer = tf.keras.layers.Dense(units=original_dim, activation=tf.nn.relu)
  
    def call(self, code):
        activation1 = self.hidden_layer1(code)
        activation2 = self.hidden_layer2(activation1)
        return self.output_layer(activation2)

class Autoencoder(tf.keras.Model):
  def __init__(self, intermediate_dim, original_dim):
    super(Autoencoder, self).__init__()
    self.loss = []
    self.encoder = Encoder(intermediate_dim=intermediate_dim)
    self.decoder = Decoder(intermediate_dim=intermediate_dim, original_dim=original_dim)

  def call(self, input_features):
    code = self.encoder(input_features)
    reconstructed = self.decoder(code)
    return reconstructed

def loss(preds, real):
  return tf.reduce_mean(tf.square(tf.subtract(preds, real)))

def train(loss, model, opt, original):
  with tf.GradientTape() as tape:
    preds = model(original)
    reconstruction_error = loss(preds, original)
  gradients = tape.gradient(reconstruction_error, model.trainable_variables)
  gradient_variables = zip(gradients, model.trainable_variables)
  opt.apply_gradients(gradient_variables)
  
  return reconstruction_error

def train_loop(model, opt, loss, dataset, epochs):
  for epoch in range(epochs):
    epoch_loss = 0
    for step, batch_features in enumerate(dataset):
      loss_values = train(loss, model, opt, batch_features)
      epoch_loss += loss_values
    model.loss.append(epoch_loss)
    print('Epoch {}/{}. Loss: {}'.format(epoch + 1, epochs, epoch_loss.numpy()))
from tensorflow.keras.datasets import mnist
(x_train, _), (x_test, _) = mnist.load_data()

x_train = x_train / 255.

x_train = x_train.astype(np.float32)
x_train = np.reshape(x_train, (x_train.shape[0], 784))
x_test = np.reshape(x_test, (x_test.shape[0], 784))

training_dataset = tf.data.Dataset.from_tensor_slices(x_train).batch(256)

model = Autoencoder(intermediate_dim=32, original_dim=784)
opt = tf.keras.optimizers.Adam(learning_rate=1e-2)
train_loop(model, opt, loss, training_dataset, 100)

plt.plot(range(100), model.loss)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

number = 10  # how many digits we will display
plt.figure(figsize=(20, 4))
for index in range(number):
    # display original
    ax = plt.subplot(2, number, index + 1)
    plt.imshow(x_test[index].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display reconstruction
    ax = plt.subplot(2, number, index + 1 + number)
    plt.imshow(model(x_test)[index].numpy().reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
# Out:
# Epoch 1/100. Loss: 13.808391571044922
# Epoch 2/100. Loss: 10.828879356384277
# Epoch 3/100. Loss: 9.607739448547363
# Epoch 4/100. Loss: 9.208849906921387
# Epoch 5/100. Loss: 9.0415678024292
# Epoch 6/100. Loss: 8.926262855529785
# Epoch 7/100. Loss: 8.792013168334961
# Epoch 8/100. Loss: 8.757332801818848
# Epoch 9/100. Loss: 8.709709167480469
# Epoch 10/100. Loss: 8.657160758972168
# Epoch 11/100. Loss: 8.649397850036621
# Epoch 12/100. Loss: 8.607895851135254
# Epoch 13/100. Loss: 8.619271278381348
# Epoch 14/100. Loss: 8.57680606842041
# Epoch 15/100. Loss: 8.620593070983887
# Epoch 16/100. Loss: 8.574484825134277
# Epoch 17/100. Loss: 8.540484428405762
# Epoch 18/100. Loss: 8.554587364196777
# Epoch 19/100. Loss: 8.549907684326172
# Epoch 20/100. Loss: 8.499568939208984
# Epoch 21/100. Loss: 8.523048400878906
# Epoch 22/100. Loss: 8.500411987304688
# Epoch 23/100. Loss: 8.532356262207031
# Epoch 24/100. Loss: 8.507013320922852
# Epoch 25/100. Loss: 8.53045654296875
# Epoch 26/100. Loss: 8.47815227508545
# Epoch 27/100. Loss: 8.475990295410156
# Epoch 28/100. Loss: 8.44528865814209
# Epoch 29/100. Loss: 8.470023155212402
# Epoch 30/100. Loss: 8.465331077575684
# Epoch 31/100. Loss: 8.450352668762207
# Epoch 32/100. Loss: 8.447183609008789
# Epoch 33/100. Loss: 8.49523639678955
# Epoch 34/100. Loss: 8.464411735534668
# Epoch 35/100. Loss: 8.447983741760254
# Epoch 36/100. Loss: 8.440155029296875
# Epoch 37/100. Loss: 8.456827163696289
# Epoch 38/100. Loss: 8.424574851989746
# Epoch 39/100. Loss: 8.477262496948242
# Epoch 40/100. Loss: 8.414770126342773
# Epoch 41/100. Loss: 8.355171203613281
# Epoch 42/100. Loss: 8.399584770202637
# Epoch 43/100. Loss: 8.393278121948242
# Epoch 44/100. Loss: 8.392732620239258
# Epoch 45/100. Loss: 8.384978294372559
# Epoch 46/100. Loss: 8.382192611694336
# Epoch 47/100. Loss: 8.35771369934082
# Epoch 48/100. Loss: 8.372453689575195
# Epoch 49/100. Loss: 8.370830535888672
# Epoch 50/100. Loss: 8.391827583312988
# Epoch 51/100. Loss: 8.44903564453125
# Epoch 52/100. Loss: 8.530627250671387
# Epoch 53/100. Loss: 8.397453308105469
# Epoch 54/100. Loss: 8.37752914428711
# Epoch 55/100. Loss: 8.372349739074707
# Epoch 56/100. Loss: 8.361125946044922
# Epoch 57/100. Loss: 8.371687889099121
# Epoch 58/100. Loss: 8.453364372253418
# Epoch 59/100. Loss: 8.413247108459473
# Epoch 60/100. Loss: 8.408846855163574
# Epoch 61/100. Loss: 8.375765800476074
# Epoch 62/100. Loss: 8.368124961853027
# Epoch 63/100. Loss: 8.369233131408691
# Epoch 64/100. Loss: 8.362820625305176
# Epoch 65/100. Loss: 8.417813301086426
# Epoch 66/100. Loss: 8.35144329071045
# Epoch 67/100. Loss: 8.34261703491211
# Epoch 68/100. Loss: 8.348713874816895
# Epoch 69/100. Loss: 8.35733699798584
# Epoch 70/100. Loss: 8.412201881408691
# Epoch 71/100. Loss: 8.40929126739502
# Epoch 72/100. Loss: 8.362804412841797
# Epoch 73/100. Loss: 8.370444297790527
# Epoch 74/100. Loss: 8.406822204589844
# Epoch 75/100. Loss: 8.370414733886719
# Epoch 76/100. Loss: 8.393980026245117
# Epoch 77/100. Loss: 8.372559547424316
# Epoch 78/100. Loss: 8.506470680236816
# Epoch 79/100. Loss: 8.441359519958496
# Epoch 80/100. Loss: 8.459041595458984
# Epoch 81/100. Loss: 8.388214111328125
# Epoch 82/100. Loss: 8.364520072937012
# Epoch 83/100. Loss: 8.347684860229492
# Epoch 84/100. Loss: 8.332895278930664
# Epoch 85/100. Loss: 8.335793495178223
# Epoch 86/100. Loss: 8.332231521606445
# Epoch 87/100. Loss: 8.345929145812988
# Epoch 88/100. Loss: 8.329439163208008
# Epoch 89/100. Loss: 8.351036071777344
# Epoch 90/100. Loss: 8.36422061920166
# Epoch 91/100. Loss: 8.408488273620605
# Epoch 92/100. Loss: 8.37678050994873
# Epoch 93/100. Loss: 8.392719268798828
# Epoch 94/100. Loss: 8.43991470336914
# Epoch 95/100. Loss: 8.351000785827637
# Epoch 96/100. Loss: 8.33939266204834
# Epoch 97/100. Loss: 8.357279777526855
# Epoch 98/100. Loss: 8.324538230895996
# Epoch 99/100. Loss: 8.326340675354004
# Epoch 100/100. Loss: 8.33726692199707

# %% [markdown]
# ## **CNN BASE MODEL**

# %%
input_img = tf.keras.layers.Input(shape=(28, 28, 1)) # adapt this if using `channels_first` image data format

x = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', padding='same')(input_img)
x = tf.keras.layers.MaxPooling2D((2, 2), padding='same')(x)
x = tf.keras.layers.Conv2D(8, (3, 3), activation='relu', padding='same')(x)
x = tf.keras.layers.MaxPooling2D((2, 2), padding='same')(x)
x = tf.keras.layers.Conv2D(8, (3, 3), activation='relu', padding='same')(x)
encoded = tf.keras.layers.MaxPooling2D((2, 2), padding='same')(x)

# at this point the representation is (4, 4, 8) i.e. 128-dimensional

x = tf.keras.layers.Conv2D(8, (3, 3), activation='relu', padding='same')(encoded)
x = tf.keras.layers.UpSampling2D((2, 2))(x)
x = tf.keras.layers.Conv2D(8, (3, 3), activation='relu', padding='same')(x)
x = tf.keras.layers.UpSampling2D((2, 2))(x)
x = tf.keras.layers.Conv2D(16, (3, 3), activation='relu')(x)
x = tf.keras.layers.UpSampling2D((2, 2))(x)
decoded = tf.keras.layers.Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)

autoencoder = tf.keras.models.Model(input_img, decoded)
autoencoder.compile(optimizer='adadelta', loss='mean_squared_error')


# to train this model we will with original MNIST digits with shape (samples, 3, 28, 28) and we will just normalize pixel values between 0 and 1
# (x_train, _), (x_test, _) = load_data('../input/mnist.npz')
from tensorflow.keras.datasets import mnist
(x_train, _), (x_test, _) = mnist.load_data()

x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = np.reshape(x_train, (len(x_train), 28, 28, 1))
x_test = np.reshape(x_test, (len(x_test), 28, 28, 1))

autoencoder.fit(x_train, x_train, epochs=100, batch_size=128, 
                shuffle=True, validation_data=(x_test, x_test), 
                callbacks=[tf.keras.callbacks.TensorBoard(log_dir='./tmp/autoencoder')])

predict=autoencoder.predict(x_test)

n = 10  # how many digits we will display
plt.figure(figsize=(20, 4))
for i in range(n):
    # display original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display reconstruction
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(predict[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
# Out:
# Epoch 1/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2349 - val_loss: 0.2337
# Epoch 2/100
# 469/469 [==============================] - 3s 5ms/step - loss: 0.2321 - val_loss: 0.2308
# Epoch 3/100
# 469/469 [==============================] - 3s 5ms/step - loss: 0.2289 - val_loss: 0.2272
# Epoch 4/100
# 469/469 [==============================] - 3s 5ms/step - loss: 0.2245 - val_loss: 0.2219
# Epoch 5/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.2175 - val_loss: 0.2128
# Epoch 6/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.2047 - val_loss: 0.1954
# Epoch 7/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1807 - val_loss: 0.1657
# Epoch 8/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1504 - val_loss: 0.1401
# Epoch 9/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1323 - val_loss: 0.1294
# Epoch 10/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1251 - val_loss: 0.1251
# Epoch 11/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1218 - val_loss: 0.1227
# Epoch 12/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1199 - val_loss: 0.1212
# Epoch 13/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1185 - val_loss: 0.1201
# Epoch 14/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1176 - val_loss: 0.1193
# Epoch 15/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1168 - val_loss: 0.1187
# Epoch 16/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1162 - val_loss: 0.1181
# Epoch 17/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1157 - val_loss: 0.1177
# Epoch 18/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1153 - val_loss: 0.1173
# Epoch 19/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1149 - val_loss: 0.1169
# Epoch 20/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1145 - val_loss: 0.1166
# Epoch 21/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1142 - val_loss: 0.1162
# Epoch 22/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1139 - val_loss: 0.1159
# Epoch 23/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1135 - val_loss: 0.1155
# Epoch 24/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1131 - val_loss: 0.1151
# Epoch 25/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1127 - val_loss: 0.1146
# Epoch 26/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1122 - val_loss: 0.1141
# Epoch 27/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1117 - val_loss: 0.1135
# Epoch 28/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1110 - val_loss: 0.1127
# Epoch 29/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1103 - val_loss: 0.1119
# Epoch 30/100
# 469/469 [==============================] - 3s 5ms/step - loss: 0.1095 - val_loss: 0.1111
# Epoch 31/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1086 - val_loss: 0.1101
# Epoch 32/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1077 - val_loss: 0.1092
# Epoch 33/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1068 - val_loss: 0.1082
# Epoch 34/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1058 - val_loss: 0.1071
# Epoch 35/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1047 - val_loss: 0.1060
# Epoch 36/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1036 - val_loss: 0.1048
# Epoch 37/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1024 - val_loss: 0.1036
# Epoch 38/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1012 - val_loss: 0.1022
# Epoch 39/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0998 - val_loss: 0.1008
# Epoch 40/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0984 - val_loss: 0.0992
# Epoch 41/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0969 - val_loss: 0.0976
# Epoch 42/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0952 - val_loss: 0.0958
# Epoch 43/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0934 - val_loss: 0.0938
# Epoch 44/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0914 - val_loss: 0.0917
# Epoch 45/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0892 - val_loss: 0.0893
# Epoch 46/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0868 - val_loss: 0.0867
# Epoch 47/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0842 - val_loss: 0.0839
# Epoch 48/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0815 - val_loss: 0.0811
# Epoch 49/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0788 - val_loss: 0.0785
# Epoch 50/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0764 - val_loss: 0.0761
# Epoch 51/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0742 - val_loss: 0.0740
# Epoch 52/100
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0724 - val_loss: 0.0724
# Epoch 53/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0709 - val_loss: 0.0710
# Epoch 54/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0697 - val_loss: 0.0698
# Epoch 55/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0686 - val_loss: 0.0688
# Epoch 56/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0677 - val_loss: 0.0679
# Epoch 57/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0669 - val_loss: 0.0671
# Epoch 58/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0662 - val_loss: 0.0664
# Epoch 59/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0656 - val_loss: 0.0658
# Epoch 60/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0650 - val_loss: 0.0652
# Epoch 61/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0645 - val_loss: 0.0647
# Epoch 62/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0640 - val_loss: 0.0643
# Epoch 63/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0636 - val_loss: 0.0638
# Epoch 64/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0632 - val_loss: 0.0634
# Epoch 65/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0628 - val_loss: 0.0630
# Epoch 66/100
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0624 - val_loss: 0.0627
# Epoch 67/100
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0621 - val_loss: 0.0623
# Epoch 68/100
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0617 - val_loss: 0.0620
# Epoch 69/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0614 - val_loss: 0.0617
# Epoch 70/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0611 - val_loss: 0.0614
# Epoch 71/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0608 - val_loss: 0.0611
# Epoch 72/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0606 - val_loss: 0.0608
# Epoch 73/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0603 - val_loss: 0.0605
# Epoch 74/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0601 - val_loss: 0.0603
# Epoch 75/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0598 - val_loss: 0.0600
# Epoch 76/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0596 - val_loss: 0.0598
# Epoch 77/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0593 - val_loss: 0.0596
# Epoch 78/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0591 - val_loss: 0.0594
# Epoch 79/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0589 - val_loss: 0.0591
# Epoch 80/100
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0587 - val_loss: 0.0589
# Epoch 81/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0585 - val_loss: 0.0587
# Epoch 82/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0583 - val_loss: 0.0585
# Epoch 83/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0581 - val_loss: 0.0583
# Epoch 84/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0579 - val_loss: 0.0582
# Epoch 85/100
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0578 - val_loss: 0.0580
# Epoch 86/100
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0576 - val_loss: 0.0578
# Epoch 87/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0574 - val_loss: 0.0576
# Epoch 88/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0573 - val_loss: 0.0575
# Epoch 89/100
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0571 - val_loss: 0.0573
# Epoch 90/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0569 - val_loss: 0.0572
# Epoch 91/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0568 - val_loss: 0.0570
# Epoch 92/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0566 - val_loss: 0.0569
# Epoch 93/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0565 - val_loss: 0.0567
# Epoch 94/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0564 - val_loss: 0.0566
# Epoch 95/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0562 - val_loss: 0.0564
# Epoch 96/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0561 - val_loss: 0.0563
# Epoch 97/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0560 - val_loss: 0.0562
# Epoch 98/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0558 - val_loss: 0.0560
# Epoch 99/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0557 - val_loss: 0.0559
# Epoch 100/100
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0556 - val_loss: 0.0558

# %% [markdown]
# ## **CHANGING THE FILTER SIZE**

# %%
input_img = tf.keras.layers.Input(shape=(28, 28, 1)) # adapt this if using `channels_first` image data format

x = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', padding='same')(input_img)
x = tf.keras.layers.MaxPooling2D((4, 4), padding='same')(x)
x = tf.keras.layers.Conv2D(8, (3, 3), activation='relu', padding='same')(x)
x = tf.keras.layers.MaxPooling2D((2, 2), padding='same')(x)
x = tf.keras.layers.Conv2D(8, (3, 3), activation='relu', padding='same')(x)
encoded = tf.keras.layers.MaxPooling2D((2, 2), padding='same')(x)

# at this point the representation is (4, 4, 8) i.e. 128-dimensional

x = tf.keras.layers.Conv2D(8, (3, 3), activation='relu', padding='same')(encoded)
x = tf.keras.layers.UpSampling2D((4, 4))(x)
x = tf.keras.layers.Conv2D(8, (3, 3), activation='relu', padding='same')(x)
x = tf.keras.layers.UpSampling2D((2, 2))(x)
x = tf.keras.layers.Conv2D(16, (3, 3), activation='relu')(x)
x = tf.keras.layers.UpSampling2D((2, 2))(x)
decoded = tf.keras.layers.Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)

autoencoder = tf.keras.models.Model(input_img, decoded)
autoencoder.compile(optimizer='adadelta', loss='mean_squared_error')
autoencoder.summary()

# to train this model we will with original MNIST digits with shape (samples, 3, 28, 28) and we will just normalize pixel values between 0 and 1
# (x_train, _), (x_test, _) = load_data('../input/mnist.npz')
from tensorflow.keras.datasets import mnist
(x_train, _), (x_test, _) = mnist.load_data()

x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = np.reshape(x_train, (len(x_train), 28, 28, 1))
x_test = np.reshape(x_test, (len(x_test), 28, 28, 1))

autoencoder.fit(x_train, x_train, epochs=100, batch_size=128, 
                shuffle=True, validation_data=(x_test, x_test), 
                callbacks=[tf.keras.callbacks.TensorBoard(log_dir='./tmp/autoencoder')])

predict=autoencoder.predict(x_test)

n = 10  # how many digits we will display
plt.figure(figsize=(20, 4))
for i in range(n):
    # display original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display reconstruction
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(predict[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
# Out:
# Model: "model_51"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_54 (InputLayer)        [(None, 28, 28, 1)]       0
# _________________________________________________________________
# conv2d_423 (Conv2D)          (None, 28, 28, 16)        160
# _________________________________________________________________
# max_pooling2d_187 (MaxPoolin (None, 7, 7, 16)          0
# _________________________________________________________________
# conv2d_424 (Conv2D)          (None, 7, 7, 8)           1160
# _________________________________________________________________
# max_pooling2d_188 (MaxPoolin (None, 4, 4, 8)           0
# _________________________________________________________________
# conv2d_425 (Conv2D)          (None, 4, 4, 8)           584
# _________________________________________________________________
# max_pooling2d_189 (MaxPoolin (None, 2, 2, 8)           0
# _________________________________________________________________
# conv2d_426 (Conv2D)          (None, 2, 2, 8)           584
# _________________________________________________________________
# up_sampling2d_178 (UpSamplin (None, 8, 8, 8)           0
# _________________________________________________________________
# conv2d_427 (Conv2D)          (None, 8, 8, 8)           584
# _________________________________________________________________
# up_sampling2d_179 (UpSamplin (None, 16, 16, 8)         0
# _________________________________________________________________
# conv2d_428 (Conv2D)          (None, 14, 14, 16)        1168
# _________________________________________________________________
# up_sampling2d_180 (UpSamplin (None, 28, 28, 16)        0
# _________________________________________________________________
# conv2d_429 (Conv2D)          (None, 28, 28, 1)         145
# =================================================================
# Total params: 4,385
# Trainable params: 4,385
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2339 - val_loss: 0.2333
# Epoch 2/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.2325 - val_loss: 0.2319
# Epoch 3/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.2310 - val_loss: 0.2304
# Epoch 4/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.2296 - val_loss: 0.2289
# Epoch 5/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.2279 - val_loss: 0.2272
# Epoch 6/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.2260 - val_loss: 0.2250
# Epoch 7/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.2234 - val_loss: 0.2220
# Epoch 8/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.2198 - val_loss: 0.2178
# Epoch 9/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.2145 - val_loss: 0.2112
# Epoch 10/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.2058 - val_loss: 0.2001
# Epoch 11/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1906 - val_loss: 0.1805
# Epoch 12/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1659 - val_loss: 0.1525
# Epoch 13/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1391 - val_loss: 0.1304
# Epoch 14/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1230 - val_loss: 0.1203
# Epoch 15/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1162 - val_loss: 0.1162
# Epoch 16/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1133 - val_loss: 0.1143
# Epoch 17/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1117 - val_loss: 0.1132
# Epoch 18/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1108 - val_loss: 0.1124
# Epoch 19/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1101 - val_loss: 0.1118
# Epoch 20/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1096 - val_loss: 0.1113
# Epoch 21/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1091 - val_loss: 0.1108
# Epoch 22/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1086 - val_loss: 0.1104
# Epoch 23/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1082 - val_loss: 0.1099
# Epoch 24/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1078 - val_loss: 0.1095
# Epoch 25/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1074 - val_loss: 0.1091
# Epoch 26/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1070 - val_loss: 0.1087
# Epoch 27/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1066 - val_loss: 0.1083
# Epoch 28/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1063 - val_loss: 0.1080
# Epoch 29/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1059 - val_loss: 0.1076
# Epoch 30/100
# 469/469 [==============================] - 3s 5ms/step - loss: 0.1056 - val_loss: 0.1073
# Epoch 31/100
# 469/469 [==============================] - 3s 5ms/step - loss: 0.1053 - val_loss: 0.1070
# Epoch 32/100
# 469/469 [==============================] - 3s 5ms/step - loss: 0.1049 - val_loss: 0.1066
# Epoch 33/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1046 - val_loss: 0.1063
# Epoch 34/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1043 - val_loss: 0.1060
# Epoch 35/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1040 - val_loss: 0.1057
# Epoch 36/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1037 - val_loss: 0.1054
# Epoch 37/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1034 - val_loss: 0.1051
# Epoch 38/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1031 - val_loss: 0.1048
# Epoch 39/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1028 - val_loss: 0.1045
# Epoch 40/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1025 - val_loss: 0.1042
# Epoch 41/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1022 - val_loss: 0.1038
# Epoch 42/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1019 - val_loss: 0.1035
# Epoch 43/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1016 - val_loss: 0.1032
# Epoch 44/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1013 - val_loss: 0.1029
# Epoch 45/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1010 - val_loss: 0.1025
# Epoch 46/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1006 - val_loss: 0.1022
# Epoch 47/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1003 - val_loss: 0.1019
# Epoch 48/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1000 - val_loss: 0.1015
# Epoch 49/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0996 - val_loss: 0.1011
# Epoch 50/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0992 - val_loss: 0.1007
# Epoch 51/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0988 - val_loss: 0.1003
# Epoch 52/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0984 - val_loss: 0.0998
# Epoch 53/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0979 - val_loss: 0.0993
# Epoch 54/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0975 - val_loss: 0.0988
# Epoch 55/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0969 - val_loss: 0.0983
# Epoch 56/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0964 - val_loss: 0.0977
# Epoch 57/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0958 - val_loss: 0.0970
# Epoch 58/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0952 - val_loss: 0.0964
# Epoch 59/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0945 - val_loss: 0.0956
# Epoch 60/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0938 - val_loss: 0.0949
# Epoch 61/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0930 - val_loss: 0.0940
# Epoch 62/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0921 - val_loss: 0.0931
# Epoch 63/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0912 - val_loss: 0.0921
# Epoch 64/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0903 - val_loss: 0.0911
# Epoch 65/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0892 - val_loss: 0.0900
# Epoch 66/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0882 - val_loss: 0.0889
# Epoch 67/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0871 - val_loss: 0.0878
# Epoch 68/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0861 - val_loss: 0.0867
# Epoch 69/100
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0852 - val_loss: 0.0858
# Epoch 70/100
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0843 - val_loss: 0.0850
# Epoch 71/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0836 - val_loss: 0.0843
# Epoch 72/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0830 - val_loss: 0.0837
# Epoch 73/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0824 - val_loss: 0.0832
# Epoch 74/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0819 - val_loss: 0.0827
# Epoch 75/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0815 - val_loss: 0.0822
# Epoch 76/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0811 - val_loss: 0.0818
# Epoch 77/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0807 - val_loss: 0.0814
# Epoch 78/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0803 - val_loss: 0.0810
# Epoch 79/100
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0800 - val_loss: 0.0806
# Epoch 80/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0796 - val_loss: 0.0803
# Epoch 81/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0793 - val_loss: 0.0800
# Epoch 82/100
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0790 - val_loss: 0.0796
# Epoch 83/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0787 - val_loss: 0.0793
# Epoch 84/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0784 - val_loss: 0.0790
# Epoch 85/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0781 - val_loss: 0.0787
# Epoch 86/100
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0779 - val_loss: 0.0784
# Epoch 87/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0776 - val_loss: 0.0781
# Epoch 88/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0773 - val_loss: 0.0778
# Epoch 89/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0770 - val_loss: 0.0775
# Epoch 90/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0768 - val_loss: 0.0773
# Epoch 91/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0765 - val_loss: 0.0770
# Epoch 92/100
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0762 - val_loss: 0.0767
# Epoch 93/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0760 - val_loss: 0.0764
# Epoch 94/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0757 - val_loss: 0.0762
# Epoch 95/100
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0755 - val_loss: 0.0759
# Epoch 96/100
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0752 - val_loss: 0.0757
# Epoch 97/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0750 - val_loss: 0.0754
# Epoch 98/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0748 - val_loss: 0.0752
# Epoch 99/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0745 - val_loss: 0.0749
# Epoch 100/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0743 - val_loss: 0.0747

# %% [markdown]
# ## **ADDING 1 LAYER**

# %%
input_img = tf.keras.layers.Input(shape=(28, 28, 1)) # adapt this if using `channels_first` image data format

x = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', padding='same')(input_img)
x = tf.keras.layers.MaxPooling2D((2, 2), padding='same')(x)
x = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', padding='same')(x)
x = tf.keras.layers.MaxPooling2D((2, 2), padding='same')(x)
x = tf.keras.layers.Conv2D(8, (3, 3), activation='relu', padding='same')(x)
x = tf.keras.layers.MaxPooling2D((2, 2), padding='same')(x)
x = tf.keras.layers.Conv2D(8, (3, 3), activation='relu', padding='same')(x)
encoded = tf.keras.layers.MaxPooling2D((2, 2), padding='same')(x)

# at this point the representation is (4, 4, 8) i.e. 128-dimensional

x = tf.keras.layers.Conv2D(8, (3, 3), activation='relu', padding='same')(encoded)
x = tf.keras.layers.UpSampling2D((2, 2))(x)
x = tf.keras.layers.Conv2D(8, (3, 3), activation='relu', padding='same')(x)
x = tf.keras.layers.UpSampling2D((2, 2))(x)
x = tf.keras.layers.Conv2D(16, (3, 3), activation='relu',padding='same')(x)
x = tf.keras.layers.UpSampling2D((2, 2))(x)
x = tf.keras.layers.Conv2D(32, (3, 3), activation='relu')(x)
x = tf.keras.layers.UpSampling2D((2,2))(x)
decoded = tf.keras.layers.Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)

autoencoder = tf.keras.models.Model(input_img, decoded)
autoencoder.compile(optimizer='adadelta', loss='mean_squared_error')
autoencoder.summary()

# to train this model we will with original MNIST digits with shape (samples, 3, 28, 28) and we will just normalize pixel values between 0 and 1
# (x_train, _), (x_test, _) = load_data('../input/mnist.npz')
from tensorflow.keras.datasets import mnist
(x_train, _), (x_test, _) = mnist.load_data()

x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = np.reshape(x_train, (len(x_train), 28, 28, 1))
x_test = np.reshape(x_test, (len(x_test), 28, 28, 1))

autoencoder.fit(x_train, x_train, epochs=100, batch_size=128, 
                shuffle=True, validation_data=(x_test, x_test), 
                callbacks=[tf.keras.callbacks.TensorBoard(log_dir='./tmp/autoencoder')])

predict=autoencoder.predict(x_test)


n = 10  # how many digits we will display
plt.figure(figsize=(20, 4))
for i in range(n):
    # display original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display reconstruction
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(predict[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
# Out:
# Model: "model_48"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_51 (InputLayer)        [(None, 28, 28, 1)]       0
# _________________________________________________________________
# conv2d_400 (Conv2D)          (None, 28, 28, 32)        320
# _________________________________________________________________
# max_pooling2d_177 (MaxPoolin (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_401 (Conv2D)          (None, 14, 14, 16)        4624
# _________________________________________________________________
# max_pooling2d_178 (MaxPoolin (None, 7, 7, 16)          0
# _________________________________________________________________
# conv2d_402 (Conv2D)          (None, 7, 7, 8)           1160
# _________________________________________________________________
# max_pooling2d_179 (MaxPoolin (None, 4, 4, 8)           0
# _________________________________________________________________
# conv2d_403 (Conv2D)          (None, 4, 4, 8)           584
# _________________________________________________________________
# max_pooling2d_180 (MaxPoolin (None, 2, 2, 8)           0
# _________________________________________________________________
# conv2d_404 (Conv2D)          (None, 2, 2, 8)           584
# _________________________________________________________________
# up_sampling2d_168 (UpSamplin (None, 4, 4, 8)           0
# _________________________________________________________________
# conv2d_405 (Conv2D)          (None, 4, 4, 8)           584
# _________________________________________________________________
# up_sampling2d_169 (UpSamplin (None, 8, 8, 8)           0
# _________________________________________________________________
# conv2d_406 (Conv2D)          (None, 8, 8, 16)          1168
# _________________________________________________________________
# up_sampling2d_170 (UpSamplin (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_407 (Conv2D)          (None, 14, 14, 32)        4640
# _________________________________________________________________
# up_sampling2d_171 (UpSamplin (None, 28, 28, 32)        0
# _________________________________________________________________
# conv2d_408 (Conv2D)          (None, 28, 28, 1)         289
# =================================================================
# Total params: 13,953
# Trainable params: 13,953
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.2298 - val_loss: 0.2290
# Epoch 2/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2276 - val_loss: 0.2261
# Epoch 3/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2237 - val_loss: 0.2210
# Epoch 4/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2163 - val_loss: 0.2107
# Epoch 5/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2000 - val_loss: 0.1862
# Epoch 6/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1635 - val_loss: 0.1418
# Epoch 7/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1277 - val_loss: 0.1219
# Epoch 8/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1176 - val_loss: 0.1180
# Epoch 9/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1152 - val_loss: 0.1167
# Epoch 10/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1142 - val_loss: 0.1160
# Epoch 11/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1136 - val_loss: 0.1155
# Epoch 12/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1131 - val_loss: 0.1150
# Epoch 13/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1127 - val_loss: 0.1146
# Epoch 14/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1122 - val_loss: 0.1142
# Epoch 15/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1118 - val_loss: 0.1137
# Epoch 16/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1114 - val_loss: 0.1132
# Epoch 17/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1109 - val_loss: 0.1127
# Epoch 18/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1104 - val_loss: 0.1121
# Epoch 19/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1098 - val_loss: 0.1115
# Epoch 20/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1092 - val_loss: 0.1109
# Epoch 21/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1086 - val_loss: 0.1103
# Epoch 22/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1080 - val_loss: 0.1096
# Epoch 23/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1073 - val_loss: 0.1089
# Epoch 24/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1066 - val_loss: 0.1082
# Epoch 25/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1059 - val_loss: 0.1074
# Epoch 26/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1051 - val_loss: 0.1066
# Epoch 27/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1043 - val_loss: 0.1057
# Epoch 28/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1034 - val_loss: 0.1047
# Epoch 29/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1024 - val_loss: 0.1036
# Epoch 30/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1013 - val_loss: 0.1024
# Epoch 31/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1000 - val_loss: 0.1010
# Epoch 32/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0985 - val_loss: 0.0992
# Epoch 33/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0966 - val_loss: 0.0971
# Epoch 34/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0943 - val_loss: 0.0944
# Epoch 35/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0914 - val_loss: 0.0911
# Epoch 36/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0881 - val_loss: 0.0874
# Epoch 37/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0845 - val_loss: 0.0838
# Epoch 38/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0812 - val_loss: 0.0807
# Epoch 39/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0783 - val_loss: 0.0779
# Epoch 40/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0760 - val_loss: 0.0758
# Epoch 41/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0743 - val_loss: 0.0743
# Epoch 42/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0730 - val_loss: 0.0732
# Epoch 43/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0721 - val_loss: 0.0724
# Epoch 44/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0715 - val_loss: 0.0719
# Epoch 45/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0711 - val_loss: 0.0715
# Epoch 46/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0708 - val_loss: 0.0712
# Epoch 47/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0705 - val_loss: 0.0709
# Epoch 48/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0703 - val_loss: 0.0707
# Epoch 49/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0701 - val_loss: 0.0704
# Epoch 50/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0699 - val_loss: 0.0702
# Epoch 51/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0697 - val_loss: 0.0700
# Epoch 52/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0695 - val_loss: 0.0698
# Epoch 53/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0693 - val_loss: 0.0696
# Epoch 54/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0691 - val_loss: 0.0695
# Epoch 55/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0690 - val_loss: 0.0693
# Epoch 56/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0689 - val_loss: 0.0692
# Epoch 57/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0688 - val_loss: 0.0691
# Epoch 58/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0687 - val_loss: 0.0690
# Epoch 59/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0687 - val_loss: 0.0690
# Epoch 60/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0686 - val_loss: 0.0689
# Epoch 61/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0685 - val_loss: 0.0688
# Epoch 62/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0685 - val_loss: 0.0688
# Epoch 63/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0684 - val_loss: 0.0687
# Epoch 64/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0684 - val_loss: 0.0687
# Epoch 65/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0683 - val_loss: 0.0686
# Epoch 66/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0683 - val_loss: 0.0686
# Epoch 67/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0683 - val_loss: 0.0685
# Epoch 68/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0682 - val_loss: 0.0685
# Epoch 69/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0682 - val_loss: 0.0685
# Epoch 70/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0681 - val_loss: 0.0684
# Epoch 71/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0681 - val_loss: 0.0684
# Epoch 72/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0681 - val_loss: 0.0683
# Epoch 73/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0680 - val_loss: 0.0683
# Epoch 74/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0680 - val_loss: 0.0682
# Epoch 75/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0679 - val_loss: 0.0682
# Epoch 76/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0679 - val_loss: 0.0682
# Epoch 77/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0679 - val_loss: 0.0681
# Epoch 78/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0678 - val_loss: 0.0681
# Epoch 79/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0678 - val_loss: 0.0680
# Epoch 80/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0677 - val_loss: 0.0680
# Epoch 81/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0677 - val_loss: 0.0679
# Epoch 82/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0677 - val_loss: 0.0679
# Epoch 83/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0676 - val_loss: 0.0679
# Epoch 84/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0676 - val_loss: 0.0678
# Epoch 85/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0675 - val_loss: 0.0678
# Epoch 86/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0675 - val_loss: 0.0677
# Epoch 87/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0674 - val_loss: 0.0677
# Epoch 88/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0674 - val_loss: 0.0676
# Epoch 89/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0674 - val_loss: 0.0676
# Epoch 90/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0673 - val_loss: 0.0676
# Epoch 91/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0673 - val_loss: 0.0675
# Epoch 92/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0672 - val_loss: 0.0675
# Epoch 93/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0672 - val_loss: 0.0674
# Epoch 94/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0672 - val_loss: 0.0674
# Epoch 95/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0671 - val_loss: 0.0674
# Epoch 96/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0671 - val_loss: 0.0673
# Epoch 97/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0670 - val_loss: 0.0673
# Epoch 98/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0670 - val_loss: 0.0672
# Epoch 99/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0670 - val_loss: 0.0672
# Epoch 100/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0669 - val_loss: 0.0671

# %% [markdown]
# ## **CNN COMPLEX**
